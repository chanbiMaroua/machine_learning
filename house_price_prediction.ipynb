# %% [markdown]
# <a href="https://colab.research.google.com/github/chanbiMaroua/machine_learning/blob/main/house_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#house prediciton price
